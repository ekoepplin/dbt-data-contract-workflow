# %% [markdown]
# # Kernel smoke test
#
# Confirms the `.venv` Jupyter kernel is selectable and has the project's notebook dependencies available.

# %%
import duckdb, pandas

print(duckdb.__version__, pandas.__version__)
